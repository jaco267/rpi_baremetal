# %% [markdown]
# ### [i2c yt](https://youtu.be/sQdBa-uIHmQ?list=PLVxiWMqQvhg9FCteL7I0aohj1_YiUx1x8&t=74)
#
# - in the video
#   - rpi is i2c master
#   - arduino is i2c slave
# - in my verseion
#   - rpi is i2c master
#   - esp32 is i2c slave
# - 簡單測試以及 pinout 可以看 y_i2c_test/d1_rpi_i2c_2_esp32/readme.ipynb

# %% [markdown]
# ### new files
# - include/peripherals/i2c.h
# - include/i2c.h
# - src/i2c.c
# - src/main.c

# %% [markdown]
# ### [i2c screen todo](https://youtu.be/hLxwAkDGyHg?list=PLVxiWMqQvhg9FCteL7I0aohj1_YiUx1x8&t=13)
# - 我沒有那個螢幕所以只是跟著做
