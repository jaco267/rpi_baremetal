# %% [markdown]
# ### [yt spi](https://youtu.be/4i26lmkvbV8?list=PLVxiWMqQvhg9FCteL7I0aohj1_YiUx1x8&t=13)
# - add
#   - include/peripherals/spi.h
#   - include/spi.h
#   - src/spi.c

# %%
esp 端
```
Master sent: 0x2a
Slave  sent: 0xaa
Master sent: 0x2a
Slave  sent: 0xaa
Master sent: 0x2a
Slave  sent: 0xaa
Master sent: 0x2a
Slave  sent: 0xaa
Master sent: 0x2a
Slave  sent: 0xaa
Master sent: 0x2a
Slave  sent: 0xaa
```

rpi side 
```
send: 42  //0x2a = 16*2+10=32+10=42
receive: 170 //0xaa = 16*10 + 10 = 170
send: 42
receive: 170
send: 42
receive: 170
send: 42
receive: 170
send: 42
receive: 170
send: 42
receive: 170
send: 42
receive: 170
send: 42
receive: 170
send: 42
```
