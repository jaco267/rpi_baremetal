# %% [markdown]
# ### [yt gpu mailbox](https://youtu.be/hSJWbmiQfck?list=PLVxiWMqQvhg9FCteL7I0aohj1_YiUx1x8&t=20)
#
# - [mailbox docs](https://github.com/raspberrypi/firmware/wiki)

# %% [markdown]
# #### new file
# - include/mailbox.h
# - src/mailbox.c
# - include/mem.h
# - src/mem.c
