# %%
scp -r ./d2_rpi_master_to_receive_esp/ elton@192.168.222.222:~/Desktop
ssh elton@192.168.222.222
S...

pi$  cd d2_rpi_master_to_receive_esp/
pi$ python main.py

Received: 0x0

# %%
sudo picocom -b 115200 /dev/ttyUSB0
# or 
sudo picocom -b 115200 /dev/ttyUSB1
Ctrl + A
Ctrl + X

ls /boot/firmware
cp -r /boot/firmware/b_spi_play ~/Desktop/

# %%
pi$ python main.py   
#! 注意 esp32 有點接觸不良要稍微往兩側拉一下   
# rpi side 
```
[0]
[170]
[170]
[170]
[170]
[0]
```
# 因為是送 0xAA  所以會收到 `170 = 16*10+10` 

#* esp32 side 
```
Slave  sent: 0xaa
Master sent: 0x2a 
Slave  sent: 0xaa
Master sent: 0x2a
```
#* slave 送 0xaa,  master 送 42 = 0x2a= 16*2+10 = 32+10=42
